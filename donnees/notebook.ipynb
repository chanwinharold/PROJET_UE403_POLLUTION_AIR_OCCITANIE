# %%
import pandas as pd

# %%
df1 = pd.read_csv('brutes/donnees_socio_economiques.csv')
df1.head()
# Out:
#   code_insee_com                  nom_com niveau_vie_median_2021  \
# 0           1001  L'Abergement-Clémenciat                  25820
# 1           1002    L'Abergement-de-Varey                  24480
# 2           1004        Ambérieu-en-Bugey                  21660
# 3           1005      Ambérieux-en-Dombes                  24610
# 4           1006                  Ambléon                  24210
#
#   nb_logements_2022 Pourcentage_appartements_2022  \
# 0               379                           2.4
# 1               175                           1.1
# 2              7973                          54.1
# 3               921                          26.5
# 4                71                           4.2
#
#   pourcentage_locataires_dans_résidence_principale_2022  \
# 0                                               13.8
# 1                                                9.9
# 2                                               53.1
# 3                                               25.2
# 4                                               26.3
#
#   evolution_annuelle_moy_de_la_population_entre_2017_et_2023_en_pourcentage  \
# 0                                               1.73
# 1                                               1.43
# 2                                               2.14
# 3                                               2.03
# 4                                               0.59
#
#   population_municipale_2023 Taux_activite_tranche_15_64_en_2022
# 0                        860                                82.1
# 1                        270                                80.1
# 2                      15934                                76.7
# 3                       1906                                81.3
# 4                        115                                70.8

# %%
df2 = pd.read_csv('brutes/donnees_geo_climatiques.csv')
df2.head()
# Out:
# /tmp/ipykernel_158393/960960266.py:1: DtypeWarning: Columns (0: code_insee_com, 1: dep_code) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('brutes/donnees_geo_climatiques.csv')
#   code_insee_com                nom_com  reg_code               reg_nom  \
# 0           1001  Abergement-Clémenciat        84  Auvergne-Rhône-Alpes
# 1           1002    Abergement-de-Varey        84  Auvergne-Rhône-Alpes
# 2           1004      Ambérieu-en-Bugey        84  Auvergne-Rhône-Alpes
# 3           1005    Ambérieux-en-Dombes        84  Auvergne-Rhône-Alpes
# 4           1006                Ambléon        84  Auvergne-Rhône-Alpes
#
#   dep_code dep_nom  population  superficie_km2  densite  latitude  ...  \
# 0        1     Ain         832              16     53.0    46.153  ...
# 1        1     Ain         267               9     29.0    46.009  ...
# 2        1     Ain       14854              24    607.0    45.961  ...
# 3        1     Ain        1897              16    118.0    45.996  ...
# 4        1     Ain         113               6     19.0    45.750  ...
#
#    RR_med NBJRR1_med  NBJRR5_med  NBJRR10_med  Tmin_med  Tmax_med  \
# 0   66.00       10.0         4.0          2.0      7.05      17.1
# 1  104.80       10.0         6.0          4.0      6.60      17.6
# 2   86.85       10.0         5.0          3.0      6.30      16.6
# 3   63.80        9.0         4.0          2.0      7.05      17.1
# 4   89.80        9.0         5.0          3.0      7.30      17.5
#
#    Tens_vap_med  Force_vent_med  Insolation_med  Rayonnement_med
# 0         10.35             2.6          3059.0          12079.0
# 1         10.75             1.1          2934.0          11543.5
# 2         10.15             2.5          2934.0          11543.5
# 3         10.40             1.8          2314.0              NaN
# 4         10.30             1.8          3314.0          13004.0
#
# [5 rows x 23 columns]

# %%
df3 = pd.read_csv('brutes/mesures_occitanie_journaliere_pollution.csv')
df3.head()
# Out:
#           nom_dept    nom_com  code_insee_com                  nom_station  \
# 0  TARN-ET-GARONNE  MONTAUBAN           82121  Montauban - Ramierou Urbain
# 1  TARN-ET-GARONNE  MONTAUBAN           82121  Montauban - Ramierou Urbain
# 2  TARN-ET-GARONNE  MONTAUBAN           82121  Montauban - Ramierou Urbain
# 3  TARN-ET-GARONNE  MONTAUBAN           82121  Montauban - Ramierou Urbain
# 4  TARN-ET-GARONNE  MONTAUBAN           82121  Montauban - Ramierou Urbain
#
#   code_station typologie influence nom_poll  valeur_poll  jour  mois  annee
# 0      FR50060   Urbaine      Fond      NOX         12.7     8     1   2023
# 1      FR50060   Urbaine      Fond      NOX          9.9     9     1   2023
# 2      FR50060   Urbaine      Fond      NOX         39.1    11     1   2023
# 3      FR50060   Urbaine      Fond      NOX         68.6    12     1   2023
# 4      FR50060   Urbaine      Fond      NOX         41.8    13     1   2023

# %%
# %%sql
# SELECT ROUND(MEDIAN(valeur_poll), 2) AS valeur_poll_med, ROUND(AVG(valeur_poll), 2) AS valeur_poll_avg, *
# FROM UE403_SOCIO_ECONOMIQUES SE
# INNER JOIN UE403_GEO_CLIMATIQUES GC USING (code_insee_com)
# INNER JOIN UE403_MESURES_JOURNALIERE_POLLUTION USING (code_insee_com)
# GROUP BY code_insee_com;
# Out:
#     valeur_poll_med  valeur_poll_avg    niveau_vie_median_2021  \
# 0              9.90            22.00                     22210
# 1             10.00            15.45                     18000
# 2             54.15            51.60                     21630
# 3             12.90            19.17                     18760
# 4             61.50            59.70                     24560
# 5             62.90            64.09                     22770
# 6             10.90            12.24                     23110
# 7             10.90            14.70                     25350
# 8              0.90             9.62                     20040
# 9             37.90            36.14                     27200
# 10             0.40             0.63                     19530
# 11            17.40            30.01                     22140
# 12            12.60            21.18                     21800
# 13            64.20            64.42  N/A - secret statistique
# 14             2.70            15.92  N/A - secret statistique
# 15             7.10            22.65                     20410
# 16            14.90            20.63                     16830
# 17            66.00            65.52                     22500
# 18            62.85            60.32                     26460
# 19             7.40             8.95                     21680
# 20            20.50            34.35                     19670
# 21            65.35            63.89                     29940
# 22            14.60            17.61                     19960
# 23             8.80            10.35                     20730
# 24             5.20             6.55                     22980
# 25            14.70            22.32                     21770
# 26             5.30             5.83                     22430
# 27             9.10            19.28                     18810
# 28            12.30            21.02                     19070
# 29             4.60             7.23                     23310
# 30            28.80            37.79                     17380
# 31            67.80            66.47                     22170
# 32             8.20            10.35                     21650
# 33             7.60            19.00                     20940
# 34            13.40            22.26                     21630
# 35            12.20            23.17                     20320
#
#     nb_logements_2022  Pourcentage_appartements_2022  \
# 0               16749                           81.9
# 1               25704                           62.5
# 2                1227                           15.9
# 3               86696                           69.5
# 4                1037                           13.9
# 5                  56                            0.0
# 6                1917                           21.0
# 7               14478                           68.4
# 8                 452                           10.6
# 9                1153                           12.2
# 10               7263                           49.4
# 11             318683                           83.8
# 12              13843                           53.4
# 13                 62                            1.5
# 14                 48                            2.1
# 15              50239                           72.2
# 16              48370                           63.3
# 17                856                            9.9
# 18               9366                           50.7
# 19               1983                           19.2
# 20             184054                           86.9
# 21               4629                           17.4
# 22              33474                           81.9
# 23               1180                           23.3
# 24               7263                           59.4
# 25               2418                           55.8
# 26                196                            5.7
# 27               9910                           65.3
# 28              30401                           75.3
# 29               3508                           50.8
# 30              74540                           73.2
# 31               5925                           28.1
# 32              30811                           49.7
# 33              24061                           40.1
# 34              33070                           44.0
# 35               4482                           42.6
#
#     pourcentage_locataires_dans_résidence_principale_2022  \
# 0                                                54.0
# 1                                                59.2
# 2                                                36.4
# 3                                                57.4
# 4                                                23.5
# 5                                                 9.8
# 6                                                31.3
# 7                                                53.1
# 8                                                24.7
# 9                                                19.5
# 10                                               48.7
# 11                                               65.8
# 12                                               54.4
# 13                                               18.0
# 14                                               19.4
# 15                                               42.0
# 16                                               58.0
# 17                                               22.1
# 18                                               38.3
# 19                                               33.7
# 20                                               66.7
# 21                                               23.3
# 22                                               51.8
# 23                                               40.5
# 24                                               51.8
# 25                                               40.8
# 26                                               17.1
# 27                                               49.6
# 28                                               64.0
# 29                                               30.3
# 30                                               56.9
# 31                                               31.2
# 32                                               52.3
# 33                                               43.4
# 34                                               43.5
# 35                                               45.7
#
#     evolution_annuelle_moy_de_la_population_entre_2017_et_2023_en_pourcentage  \
# 0                                               -0.05
# 1                                                2.31
# 2                                                2.85
# 3                                                0.14
# 4                                                0.48
# 5                                               -0.15
# 6                                                0.95
# 7                                                2.00
# 8                                               -0.96
# 9                                                1.05
# 10                                               0.88
# 11                                               1.19
# 12                                               0.37
# 13                                              -1.56
# 14                                              -1.74
# 15                                               0.76
# 16                                               0.92
# 17                                              -0.94
# 18                                               0.78
# 19                                               2.30
# 20                                               1.42
# 21                                               1.12
# 22                                               0.80
# 23                                              -1.47
# 24                                               0.45
# 25                                              -0.82
# 26                                              -1.33
# 27                                              -0.15
# 28                                               1.12
# 29                                               0.16
# 30                                               0.20
# 31                                              -0.04
# 32                                               0.77
# 33                                               0.34
# 34                                               0.58
# 35                                              -1.00
#
#     population_municipale_2023  Taux_activite_tranche_15_64_en_2022  \
# 0                        23981                                 72.1
# 1                        46125                                 62.8
# 2                         2604                                 76.1
# 3                       151839                                 66.4
# 4                         2096                                 80.0
# 5                          114                                 81.5
# 6                         4310                                 81.3
# 7                        27604                                 80.3
# 8                          736                                 71.4
# 9                         2587                                 82.4
# 10                       12139                                 70.1
# 11                      514819                                 71.8
# 12                       22428                                 71.4
# 13                         101                                 71.2
# 14                          63                                 75.6
# 15                       29939                                 68.7
# 16                       81545                                 63.4
# 17                        1622                                 74.0
# 18                       17351                                 79.1
# 19                        4507                                 78.4
# 20                      310240                                 67.1
# 21                       10472                                 75.6
# 22                       45337                                 67.4
# 23                        1957                                 77.2
# 24                       12464                                 74.2
# 25                        2761                                 74.2
# 26                         347                                 75.3
# 27                       13266                                 68.9
# 28                       44399                                 64.8
# 29                         816                                 76.9
# 30                      121616                                 62.9
# 31                       11630                                 74.4
# 32                       51290                                 68.1
# 33                       42505                                 72.0
# 34                       62945                                 72.7
# 35                        6008                                 74.3
#
#     code_insee_com  ...  Insolation_med  Rayonnement_med  jour  mois  annee  \
# 0            12202  ...          3672.5          13495.0     1     1   2023
# 1            30007  ...          3865.5          13845.0     1     1   2024
# 2            30061  ...          4324.5          14620.0     1     1   2024
# 3            30189  ...          4324.5          14620.0     1     1   2023
# 4            30315  ...          4377.0          14986.0     1     1   2023
# 5            31060  ...          3605.0          15422.0     1     1   2023
# 6            31066  ...          3239.5          12941.5     1     1   2023
# 7            31069  ...          3378.0          12998.5     1     1   2023
# 8            31344  ...          3884.0          14003.0     1     1   2023
# 9            31381  ...          3982.0          14329.5     1     1   2023
# 10           31483  ...          3373.0          13106.5     1     1   2023
# 11           31555  ...          3378.0          12998.5     1     1   2023
# 12           32013  ...          3218.0          12922.0     1     1   2023
# 13           32139  ...          3522.0          13471.0     1     1   2023
# 14           32317  ...          3343.0          12575.0     1     1   2023
# 15           34003  ...          4530.5          15158.5     1     1   2023
# 16           34032  ...          4299.0          14539.5     1     1   2023
# 17           34084  ...          4299.0          14539.5     1     1   2023
# 18           34129  ...          4690.0          15794.0     1     1   2024
# 19           34146  ...          4205.0          15149.0     1     1   2023
# 20           34172  ...          4690.0          15794.0     1     1   2023
# 21           34255  ...          4690.0          15794.0     1     1   2023
# 22           34301  ...          4104.0          14498.0     1     1   2025
# 23           46029  ...             NaN              NaN     1     1   2026
# 24           48095  ...          3506.5          12843.0     1     1   2025
# 25           65025  ...          3156.0          12814.0     1     1   2023
# 26           65159  ...          3276.0          13039.0     1     1   2026
# 27           65286  ...          3156.0          12814.0     1     1   2023
# 28           65440  ...          3156.0          12814.0     1     1   2023
# 29           66020  ...          4173.0          15741.0     1     1   2025
# 30           66136  ...          4099.0          14633.5     1     1   2023
# 31           66172  ...          4099.0          14633.5     1     1   2023
# 32           81004  ...          3511.5          13241.5     1     1   2023
# 33           81065  ...          3031.0          12325.5     1     1   2023
# 34           82121  ...          3433.0          13247.0     1     1   2023
# 35            9261  ...          3208.5          12950.0     1     1   2023
#
#                      typologie     influence  nom_poll  valeur_poll  \
# 0                      Urbaine          Fond        NO         1.10
# 1                      Urbaine          Fond        NO         2.50
# 2                  Périurbaine          Fond        O3        36.50
# 3                      Urbaine          Fond        NO         0.80
# 4   Rurale proche Zone Urbaine  Industrielle        O3        46.60
# 5             Rurale Régionale          Fond        O3        62.20
# 6   Rurale proche Zone Urbaine  Industrielle      PM10        20.80
# 7                  Périurbaine        Trafic        NO         1.40
# 8                      Urbaine  Industrielle       H2S         3.70
# 9                  Périurbaine          Fond       NO2         1.90
# 10                     Urbaine  Industrielle       H2S         1.20
# 11                     Urbaine          Fond        NO         0.80
# 12                     Urbaine          Fond        NO         3.40
# 13            Rurale Régionale          Fond        O3        56.30
# 14            Rurale Nationale          Fond        NO         0.13
# 15                 Périurbaine          Fond        NO         0.60
# 16                     Urbaine        Trafic        NO         2.40
# 17            Rurale Régionale          Fond        O3        69.40
# 18                 Périurbaine          Fond        O3        62.50
# 19                 Périurbaine  Industrielle        NO         0.40
# 20                     Urbaine          Fond        NO         0.50
# 21                 Périurbaine          Fond        O3        67.90
# 22                     Urbaine        Trafic       NO2        23.50
# 23                     Urbaine          Fond      PM10        34.90
# 24                     Urbaine          Fond      PM10        16.10
# 25                     Urbaine          Fond        NO         3.50
# 26                 Périurbaine  Industrielle        NO         1.30
# 27                     Urbaine          Fond        NO         3.40
# 28                     Urbaine          Fond        NO         4.40
# 29            Rurale Régionale          Fond      PM10        15.80
# 30                     Urbaine          Fond       NO2        22.00
# 31                 Périurbaine          Fond        O3        22.80
# 32                     Urbaine          Fond        NO         2.10
# 33                     Urbaine          Fond        NO         0.60
# 34                     Urbaine          Fond        NO         2.50
# 35                     Urbaine          Fond        NO         2.10
#
#     code_station
# 0        FR50815
# 1        FR50801
# 2        FR50213
# 3        FR50211
# 4        FR50216
# 5        FR50031
# 6        FR50047
# 7        FR50043
# 8        FR50015
# 9        FR50041
# 10       FR50016
# 11       FR50030
# 12       FR50833
# 13       FR50029
# 14       FR50020
# 15       FR50210
# 16       FR50226
# 17       FR50209
# 18       FR50205
# 19       FR50206
# 20       FR50201
# 21       FR50204
# 22       FR50228
# 23       FR50066
# 24       FR50231
# 25       FR50813
# 26       FR50837
# 27       FR50042
# 28       FR50052
# 29       FR50802
# 30       FR50220
# 31       FR50221
# 32       FR50026
# 33       FR50053
# 34       FR50060
# 35       FR50826
#
# [36 rows x 35 columns]

# %%
df_sql1.head()
# Out:
#    valeur_poll_med  valeur_poll_avg niveau_vie_median_2021  nb_logements_2022  \
# 0             9.90            22.00                  22210              16749
# 1            10.00            15.45                  18000              25704
# 2            54.15            51.60                  21630               1227
# 3            12.90            19.17                  18760              86696
# 4            61.50            59.70                  24560               1037
#
#    Pourcentage_appartements_2022  \
# 0                           81.9
# 1                           62.5
# 2                           15.9
# 3                           69.5
# 4                           13.9
#
#    pourcentage_locataires_dans_résidence_principale_2022  \
# 0                                               54.0
# 1                                               59.2
# 2                                               36.4
# 3                                               57.4
# 4                                               23.5
#
#    evolution_annuelle_moy_de_la_population_entre_2017_et_2023_en_pourcentage  \
# 0                                              -0.05
# 1                                               2.31
# 2                                               2.85
# 3                                               0.14
# 4                                               0.48
#
#    population_municipale_2023  Taux_activite_tranche_15_64_en_2022  \
# 0                       23981                                 72.1
# 1                       46125                                 62.8
# 2                        2604                                 76.1
# 3                      151839                                 66.4
# 4                        2096                                 80.0
#
#    code_insee_com  ...  Insolation_med  Rayonnement_med  jour  mois  annee  \
# 0           12202  ...          3672.5          13495.0     1     1   2023
# 1           30007  ...          3865.5          13845.0     1     1   2024
# 2           30061  ...          4324.5          14620.0     1     1   2024
# 3           30189  ...          4324.5          14620.0     1     1   2023
# 4           30315  ...          4377.0          14986.0     1     1   2023
#
#                     typologie     influence  nom_poll  valeur_poll  \
# 0                     Urbaine          Fond        NO          1.1
# 1                     Urbaine          Fond        NO          2.5
# 2                 Périurbaine          Fond        O3         36.5
# 3                     Urbaine          Fond        NO          0.8
# 4  Rurale proche Zone Urbaine  Industrielle        O3         46.6
#
#    code_station
# 0       FR50815
# 1       FR50801
# 2       FR50213
# 3       FR50211
# 4       FR50216
#
# [5 rows x 35 columns]

# %%
df_sql1.select_dtypes(include=['float', 'int']).columns
# Out:
# Index(['valeur_poll_med', 'valeur_poll_avg', 'nb_logements_2022',
#        'Pourcentage_appartements_2022',
#        'pourcentage_locataires_dans_résidence_principale_2022',
#        'evolution_annuelle_moy_de_la_population_entre_2017_et_2023_en_pourcentage',
#        'population_municipale_2023', 'Taux_activite_tranche_15_64_en_2022',
#        'code_insee_com', 'population', 'superficie_km2', 'densite', 'latitude',
#        'longitude', 'alti_med', 'RR_med', 'NBJRR1_med', 'NBJRR5_med',
#        'NBJRR10_med', 'Tmin_med', 'Tmax_med', 'Tens_vap_med', 'Force_vent_med',
#        'Insolation_med', 'Rayonnement_med', 'jour', 'mois', 'annee',
#        'valeur_poll'],
#       dtype='str')
